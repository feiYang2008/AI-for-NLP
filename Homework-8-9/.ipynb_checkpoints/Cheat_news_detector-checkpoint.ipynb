# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
# ms-python.python added
import os
try:
	os.chdir(os.path.join(os.getcwd(), '..'))
	print(os.getcwd())
except:
	pass

# %% [markdown]
#  ### Convert sentence into TFIDF sequence

# %%
import pandas as pd
import os
import sklearn
import re
import pickle
from sklearn import model_selection
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import jieba

# %%
# vectorizer = TfidfVectorizer(max_features=30000)
# x_text = vectorizer.fit_transform(da['text'])
vectorizer = pickle.load(open('Homework-8-9/vectorizer', 'rb'))
x_text = vectorizer.transform(da['text'])

# %%
print(os.listdir())
# Out:
# ['Homework-4', 'Homework-7', '.vscode', 'mysql-remote Session.sql', 'Homework-2', 'Homework-1', 'test.jpg', '.gitignore', 'Homework-3', 'tree_model', 'Homework-8-9', '.git', '.sfdx']

# %%
print(x_text.shape)
# Out:
# (89611, 30000)

# %% [markdown]
#  ## Load Data into Python from Json

# %%
fp = open('Homework-8-9/news.json', 'r', encoding='utf-8')
da = pd.read_json('Homework-8-9/news.json', encoding='utf-8')
da.head(10)
# Out:
#        author                                            content  \
# 0              此外，自本周（6月12日）起，除小米手机6等15款机型外，其余机型已暂停更新发布（含开发版/...
# 1              骁龙835作为唯一通过Windows 10桌面平台认证的ARM处理器，高通强调，不会因为只考...
# 2              此前的一加3T搭载的是3400mAh电池，DashCharge快充规格为5V/4A。\n至于...
# 3                  这是6月18日在葡萄牙中部大佩德罗冈地区拍摄的被森林大火烧毁的汽车。新华社记者张立云摄\n
# 4  胡淑丽_MN7479  （原标题：44岁女子跑深圳约会网友被拒，暴雨中裸身奔走……）\n@深圳交警微博称：昨日清晨交...
# 5          张怡  　　受到A股被纳入MSCI指数的利好消息刺激，A股市场从周三开始再度上演龙马行情，周四上午金...
# 6              虽然至今夏普智能手机在市场上无法排得上号，已经完全没落，并于 2013 年退出中国市场，但是...
# 7      申玉彬 整理  　　沙漠雄鹰：震荡有利消化套牢筹码\n　　周四开盘上证50在银行券商大蓝筹带动下一度涨近2%...
# 8  李杭_BJS4645  （原标题：武汉警方一下子抓了808人，还都是俊男靓女！原来他们每天偷偷摸摸干这事！）\n武汉...
# 9          吴瞬  　　6月21日，A股纳入MSCI指数尘埃落定，但当天被寄予厚望的券商股并未扛起反弹大旗。22...
#
#                                              feature     id  \
# 0  {"type":"科技","site":"cnbeta","commentNum":"37"...  89617
# 1  {"type":"科技","site":"cnbeta","commentNum":"15"...  89616
# 2  {"type":"科技","site":"cnbeta","commentNum":"18"...  89615
# 3  {"type":"国际新闻","site":"环球","commentNum":"0","j...  89614
# 4  {"type":"新闻","site":"网易热门","commentNum":"978",...  89613
# 5  {"type":"市场","site":"中证网","commentNum":"0","jo...  89612
# 6  {"type":"科技","site":"cnbeta","commentNum":"21"...  89611
# 7  {"type":"市场","site":"中证网","commentNum":"0","jo...  89610
# 8  {"type":"新闻","site":"网易热门","commentNum":"1600"...  89609
# 9  {"type":"市场","site":"中证网","commentNum":"0","jo...  89608
#
#                      source                          title  \
# 0    快科技@http://www.kkj.cn/           小米MIUI 9首批机型曝光：共计15款
# 1    快科技@http://www.kkj.cn/     骁龙835在Windows 10上的性能表现有望改善
# 2    快科技@http://www.kkj.cn/      一加手机5细节曝光：3300mAh、充半小时用1天
# 3                       新华社  葡森林火灾造成至少62人死亡 政府宣布进入紧急状态（组图）
# 4                     深圳大件事       44岁女子约网友被拒暴雨中裸奔 交警为其披衣相随
# 5                 中国证券报?中证网                 金融股一枝独秀 配置价值犹存
# 6  威锋网@http://www.feng.com/            配骁龙660 全面屏鼻祖夏普新机酝酿中
# 7                 中国证券报?中证网                博友早评：震荡有利消化套牢筹码
# 8                 荆楚网-楚天都市报       武汉千余警察出动 抓获808名俊男靓女全是诈骗犯
# 9                 中国证券报?中证网            纳入MSCI指数 A股长期配置价值提升
#
#                                                  url
# 0     http://www.cnbeta.com/articles/tech/623597.htm
# 1     http://www.cnbeta.com/articles/tech/623599.htm
# 2     http://www.cnbeta.com/articles/tech/623601.htm
# 3  http://world.huanqiu.com/hot/2017-06/10866126....
# 4  http://news.163.com/17/0618/00/CN617P3Q0001875...
# 5  http://www.cs.com.cn/gppd/201706/t20170623_533...
# 6     http://www.cnbeta.com/articles/tech/623603.htm
# 7  http://www.cs.com.cn/gppd/201706/t20170623_533...
# 8  http://news.163.com/17/0614/14/CMT9N8G80001899...
# 9  http://www.cs.com.cn/gppd/201706/t20170623_533...

# %% [markdown]
#  ### Train test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_text, da['label'], test_size=0.3) 
print(x_train.shape)
print(x_test.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-2afa6174a0fc> in <module>()
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(x_text, da['label'], test_size=0.3)
#       2 print(x_train.shape)
#       3 print(x_test.shape)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'

# %% [markdown]
#  ## Pre-process data
#  1. Remove characters "新华社"
#  2. Create labels according to the source

# %%
da['label'] = da['source'].str.contains('新华').astype('int')
da.head(10)
# Out:
#        author                                            content  \
# 0              此外，自本周（6月12日）起，除小米手机6等15款机型外，其余机型已暂停更新发布（含开发版/...
# 1              骁龙835作为唯一通过Windows 10桌面平台认证的ARM处理器，高通强调，不会因为只考...
# 2              此前的一加3T搭载的是3400mAh电池，DashCharge快充规格为5V/4A。\n至于...
# 3                  这是6月18日在葡萄牙中部大佩德罗冈地区拍摄的被森林大火烧毁的汽车。新华社记者张立云摄\n
# 4  胡淑丽_MN7479  （原标题：44岁女子跑深圳约会网友被拒，暴雨中裸身奔走……）\n@深圳交警微博称：昨日清晨交...
# 5          张怡  　　受到A股被纳入MSCI指数的利好消息刺激，A股市场从周三开始再度上演龙马行情，周四上午金...
# 6              虽然至今夏普智能手机在市场上无法排得上号，已经完全没落，并于 2013 年退出中国市场，但是...
# 7      申玉彬 整理  　　沙漠雄鹰：震荡有利消化套牢筹码\n　　周四开盘上证50在银行券商大蓝筹带动下一度涨近2%...
# 8  李杭_BJS4645  （原标题：武汉警方一下子抓了808人，还都是俊男靓女！原来他们每天偷偷摸摸干这事！）\n武汉...
# 9          吴瞬  　　6月21日，A股纳入MSCI指数尘埃落定，但当天被寄予厚望的券商股并未扛起反弹大旗。22...
#
#                                              feature     id  \
# 0  {"type":"科技","site":"cnbeta","commentNum":"37"...  89617
# 1  {"type":"科技","site":"cnbeta","commentNum":"15"...  89616
# 2  {"type":"科技","site":"cnbeta","commentNum":"18"...  89615
# 3  {"type":"国际新闻","site":"环球","commentNum":"0","j...  89614
# 4  {"type":"新闻","site":"网易热门","commentNum":"978",...  89613
# 5  {"type":"市场","site":"中证网","commentNum":"0","jo...  89612
# 6  {"type":"科技","site":"cnbeta","commentNum":"21"...  89611
# 7  {"type":"市场","site":"中证网","commentNum":"0","jo...  89610
# 8  {"type":"新闻","site":"网易热门","commentNum":"1600"...  89609
# 9  {"type":"市场","site":"中证网","commentNum":"0","jo...  89608
#
#                      source                          title  \
# 0    快科技@http://www.kkj.cn/           小米MIUI 9首批机型曝光：共计15款
# 1    快科技@http://www.kkj.cn/     骁龙835在Windows 10上的性能表现有望改善
# 2    快科技@http://www.kkj.cn/      一加手机5细节曝光：3300mAh、充半小时用1天
# 3                       新华社  葡森林火灾造成至少62人死亡 政府宣布进入紧急状态（组图）
# 4                     深圳大件事       44岁女子约网友被拒暴雨中裸奔 交警为其披衣相随
# 5                 中国证券报?中证网                 金融股一枝独秀 配置价值犹存
# 6  威锋网@http://www.feng.com/            配骁龙660 全面屏鼻祖夏普新机酝酿中
# 7                 中国证券报?中证网                博友早评：震荡有利消化套牢筹码
# 8                 荆楚网-楚天都市报       武汉千余警察出动 抓获808名俊男靓女全是诈骗犯
# 9                 中国证券报?中证网            纳入MSCI指数 A股长期配置价值提升
#
#                                                  url  label
# 0     http://www.cnbeta.com/articles/tech/623597.htm      0
# 1     http://www.cnbeta.com/articles/tech/623599.htm      0
# 2     http://www.cnbeta.com/articles/tech/623601.htm      0
# 3  http://world.huanqiu.com/hot/2017-06/10866126....      1
# 4  http://news.163.com/17/0618/00/CN617P3Q0001875...      0
# 5  http://www.cs.com.cn/gppd/201706/t20170623_533...      0
# 6     http://www.cnbeta.com/articles/tech/623603.htm      0
# 7  http://www.cs.com.cn/gppd/201706/t20170623_533...      0
# 8  http://news.163.com/17/0614/14/CMT9N8G80001899...      0
# 9  http://www.cs.com.cn/gppd/201706/t20170623_533...      0

# %% [markdown]
#  ### Build Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
def get_performance(model, X_, y_):
    y_hat = model.predict(X_)
    y_prob = model.predict_proba(X_)
    print('percision is: {}'.format(precision_score(y_, y_hat)))
    print('recall is: {}'.format(recall_score(y_, y_hat)))
    print('roc_auc is: {}'.format(roc_auc_score(y_, y_hat)))
    print('confusion matrix: \n{}'.format(confusion_matrix(y_, y_hat, labels=[0, 1])))

# %%
pattern = re.compile('^新华社')
da['content'].fillna('')
da['text'] = da['content'].apply(lambda x: re.sub(pattern, '', x.strip()))
da[da['label'] == 1].head(100)
# Out:
#            author                                            content  \
# 3                      这是6月18日在葡萄牙中部大佩德罗冈地区拍摄的被森林大火烧毁的汽车。新华社记者张立云摄\n
# 17                 国歌法草案首次提请最高立法机关审议\n点击图片进入下一页\n新闻：十二届全国人大常委会第二十...
# 25                 当地时间2017年6月17日，土耳其马尼萨省，在土耳其第1步兵训练大队司令部军营，590名土...
# 27                 英国与欧盟的“脱欧”谈判于19日正式开始。然而此时，英国首相特雷莎·梅正面临着空前的政治压力...
# 39                     这是6月18日在葡萄牙中部大佩德罗冈地区拍摄的被森林大火烧毁的汽
#
#                                                 feature     id    source  \
# 3     {"type":"国际新闻","site":"环球","commentNum":"0","j...  89614       新华社
# 17    {"type":"观点滚动","site":"参考消息","commentNum":"0",...  89600       新华网
# 25    {"type":"国际新闻","site":"环球","commentNum":"0","j...  89592       新华网
# 27    {"type":"国际新闻","site":"环球","commentNum":"0","j...  89590       新华网
# 39    {"type":"国际新闻","site":"环球","commentNum":"0","j...  89578       新华社
# 51    {"type":"国内新闻","site":"环球","commentNum":"0","j...  89566       新华网
# 65    {"type":"科技","site":"cnbeta","commentNum":"5",...  89552      新华社@
# 95    {"type":"国内新闻","site":"环球","commentNum":"0","j...  89522       新华社
# 104   {"type":"金融市场","site":"参考消息","commentNum":"0",...  89513       新华网
# 113   {"type":"国内新闻","site":"环球","commentNum":"0","j...  89504       新华社
# 231   {"type":"娱乐","site":"环球","commentNum":"0","joi...  89386       新华网
# 305   {"type":"国内新闻","site":"环球","commentNum":"0","j...  89312       新华社
# 312   {"type":"国内新闻","site":"环球","commentNum":"0","j...  89305       新华社
# 314   {"type":"国内新闻","site":"环球","commentNum":"0","j...  89303       新华社
# 329   {"type":"社会观察","site":"参考消息","commentNum":"0",...  89288       新华网
# 330   {"type":"社会观察","site":"参考消息","commentNum":"0",...  89287       新华网
# 331   {"type":"社会观察","site":"参考消息","commentNum":"0",...  89286       新华网
# 335   {"type":"社会观察","site":"参考消息","commentNum":"0",...  89282       新华网
# 365   {"type":"社会观察","site":"参考消息","commentNum":"0",...  89252       新华网
# 376   {"type":"社会观察","site":"参考消息","commentNum":"0",...  89241       新华网
# 388   {"type":"社会观察","site":"参考消息","commentNum":"0",...  89229       新华网
# 445   {"type":"社会观察","site":"参考消息","commentNum":"0",...  89172       新华网
# 446   {"type":"社会观察","site":"参考消息","commentNum":"0",...  89171       新华网
# 448   {"type":"社会观察","site":"参考消息","commentNum":"0",...  89169       新华网
# 511   {"type":"国际","site":"头条","commentNum":"146","j...  89106       新华网
# 514   {"type":"国际","site":"头条","commentNum":"146","j...  89103       新华网
# 541   {"type":"体育","site":"凤凰","commentNum":"739","j...  89076     新华通讯社
# 543   {"type":"旅游","site":"环球","commentNum":"0","joi...  89074       新华社
# 545   {"type":"体育","site":"新浪","commentNum":" 50","j...  89072       新华社
# 552   {"type":"社会观察","site":"参考消息","commentNum":"0",...  89065       新华网
# ...                                                 ...    ...       ...
# 903   {"type":"时事要闻","site":"参考消息","commentNum":"0",...  88714       新华网
# 909   {"type":"新闻","site":"新浪热门","commentNum":" 392"...  88708       新华社
# 910   {"type":"时事要闻","site":"参考消息","commentNum":"0",...  88707       新华网
# 913   {"type":"时事要闻","site":"参考消息","commentNum":"0",...  88704       新华网
# 931   {"type":"海外","site":"中证网","commentNum":"0","jo...  88686       新华社
# 934   {"type":"海外","site":"中证网","commentNum":"0","jo...  88683       新华社
# 937   {"type":"海外","site":"中证网","commentNum":"0","jo...  88680       新华社
# 940   {"type":"海外","site":"中证网","commentNum":"0","jo...  88677       新华社
# 943   {"type":"海外","site":"中证网","commentNum":"0","jo...  88674       新华社
# 946   {"type":"海外","site":"中证网","commentNum":"0","jo...  88671       新华社
# 951   {"type":"海外","site":"中证网","commentNum":"0","jo...  88666       新华社
# 954   {"type":"海外","site":"中证网","commentNum":"0","jo...  88663       新华社
# 958   {"type":"海外","site":"中证网","commentNum":"0","jo...  88659       新华社
# 964   {"type":"海外","site":"中证网","commentNum":"0","jo...  88653       新华社
# 966   {"type":"海外","site":"中证网","commentNum":"0","jo...  88651       新华社
# 982   {"type":"新闻","site":"新浪热门","commentNum":" 32",...  88635       新华网
# 990   {"type":"海外","site":"中证网","commentNum":"0","jo...  88627       新华社
# 994   {"type":"社会观察","site":"参考消息","commentNum":"0",...  88623       新华网
# 995   {"type":"海外","site":"中证网","commentNum":"0","jo...  88622       新华社
# 999   {"type":"时事要闻","site":"参考消息","commentNum":"0",...  88618       新华网
# 1002  {"type":"时事要闻","site":"参考消息","commentNum":"0",...  88615       新华网
# 1005  {"type":"海外","site":"中证网","commentNum":"0","jo...  88612       新华社
# 1006  {"type":"社会","site":"网易","commentNum":"6","joi...  88611       新华网
# 1008  {"type":"时事要闻","site":"参考消息","commentNum":"0",...  88609       新华网
# 1009  {"type":"海外","site":"中证网","commentNum":"0","jo...  88608       新华社
# 1011  {"type":"海外","site":"中证网","commentNum":"0","jo...  88606       新华社
# 1015  {"type":"海外","site":"中证网","commentNum":"0","jo...  88602       新华社
# 1017  {"type":"海外","site":"中证网","commentNum":"0","jo...  88600       新华网
# 1066  {"type":"海外","site":"中证网","commentNum":"0","jo...  88551       新华社
# 1103  {"type":"新闻","site":"网易热门","commentNum":"1166"...  88514  新华社新媒体专线
#
#                                title  \
# 3      葡森林火灾造成至少62人死亡 政府宣布进入紧急状态（组图）
# 17                 [及时点]我们不需要“百变老太太”
# 25       土耳其近590名士兵疑食物中毒 被送往医院救治（组图）
# 27         火灾与脱欧炙烤英国首相 特雷莎·梅面临空前政治压力
# 39         葡森林火灾造成至少62人死亡 政府宣布进入紧急状态
# 51         大漠变通途——世界上最长的穿越沙漠高速公路建设纪实
# 65         高考志愿填报：眼花缭乱的App、上万元咨询靠谱吗？
# 95                   综述：亚投行第二届年会三大亮点
# 104             粤港澳概念板块午后走强 珠海港等个股领涨
# 113             《军营理论热点怎么看·2017》印发全军
# 231            林志玲非洲选美气质出众 网友：美出国际范儿
# 305     甘肃力推网络扶贫：贫困山区到2020年实现4G网络全覆盖
# 312                   天山天池首次举办山地马拉松赛
# 314             9省市联动开展跨区域地震救援实战拉动演练
# 329          “２０１７中国最具幸福感城市”调查推选活动启动
# 330         云南机场公安严打“空中贩毒”3年缴毒逾600公斤
# 331                      气象专家解析京津冀降雨
# 335                      气象专家解析京津冀降雨
# 365                黑龙江自然环境改善迎来更多鸟飞鹤鸣
# 376                安徽不断将跨省流域补偿试点推向深入
# 388    “悟空”为何跌下共享风口？——重庆首家共享单车“退市”观察
# 445            贵州对一批重大火灾隐患单位实施“挂牌督办”
# 446                   广东探索东西部扶贫协作新路径
# 448             江苏成立VR/AR产业联盟链接上下游企业
# 511                 特朗普被查！FBI这次动真格了？
# 514                 特朗普被查！FBI这次动真格了？
# 958      国际油价２０日下跌，７月交货的纽约轻质原油期货价格下跌０．９７美元，收于每桶４３．２３美元。
# 964   伦敦股市《金融时报》１００种股票平均价格指数２０日报收于７４７２．７１点，比前一交易日下跌５...
# 966   巴黎股市ＣＡＣ４０股指２０日尾盘报收于５２９３．６５点，较前一交易日下跌１７．０７点，跌幅为...
# 982   上海6月19日电 ?题：70城楼市稳中有降 热点调控城市“降温”明显\n　　新华社记者郑钧天...
# 990   纽约股市三大股指２０日下跌，其中道指跌０．２９％，标普指数跌０．６７％，纳斯达克指数跌０．８２％。
# 994   兰州６月２3日电（记者 张文静）从甘肃省会城市兰州出发，秦翔带领团队驱车一路向西千余公里，眼...
# 995   纽约商品交易所黄金期货市场交投最活跃的８月黄金期价２０日比前一交易日下跌３．２美元，收于每盎...
# 999   点击图片进入下一页\n2016年9月21日,自行车选手们在萍乡武功山景区内骑行。新华社记者周...
# 1002  兰州６月２3日电（记者 张文静）从甘肃省会城市兰州出发，秦翔带领团队驱车一路向西千余公里，眼...
# 1005    德国法兰克福股市ＤＡＸ指数２０日下跌７４．１６点，跌幅为０．５８％，报收于１２８１４．７９点。
# 1006  （原标题：江苏立法禁机场“天价面条” 签协议需明确价格）\n“机场管理机构应当按照公平竞争、...
# 1008  原标题：生态文明试验区迎来“周年考” 来自首批国家生态文明试验区的江西观察\n点击图片进入下...
# 1009  芝加哥期货交易所２０日玉米、小麦和大豆期价涨跌不一。\n　　当天，芝加哥期货交易所玉米市场交...
# 1011  伦敦股市《金融时报》１００种股票平均价格指数２０日报收于７４７２．７１点，比前一交易日下跌５...
# 1015  纽约商品交易所黄金期货市场交投最活跃的８月黄金期价２０日比前一交易日下跌３．２美元，收于每盎...
# 1017  我们现在拥有强大而稳定的领导力，不过是在法国，而非英国。英国首相特雷莎 梅将在英国大选后领导...
# 1066  惠灵顿６月２１日电（记者宿亮）全球乳制品贸易平台２１日公布的数据显示，在最新一次拍卖中，全球...
# 1103  （原标题：普京向科米喊话：若受迫害，来俄罗斯避难吧）\n6月15日，俄罗斯总统普京在年度“与...
#
# [100 rows x 9 columns]

# %% [markdown]
#  ### Logistic Regression

# %%
lr_model = LogisticRegression()
lr_model.fit(x_train, y_train)
get_performance(lr_model, x_test.toarray(), y_test)
# Out:
# /home/yikang/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# percision is: 0.9732671218704738
# recall is: 0.9947132464895957
# roc_auc is: 0.8976652652201065
# confusion matrix:
# [[ 2594   646]
#  [  125 23519]]

# %% [markdown]
#  ### Cut the sentence into words (using jieba)

# %%
def cut(string):
    return ' '.join(jieba.cut(string))
da['text'] = da['text'].apply(cut)

# %%
y_hat = lr_model.predict(x_test)
print(y_hat)
y_score = lr_model.predict_proba(x_test)[:,1]
print(roc_auc_score(y_test, y_score))
get_performance(lr_model, x_test.toarray(), y_test)
# Out:
# [1 1 1 ... 1 0 1]
# 0.9927444855897458
# percision is: 0.9732671218704738
# recall is: 0.9947132464895957
# roc_auc is: 0.8976652652201065
# confusion matrix:
# [[ 2594   646]
#  [  125 23519]]

# %% [markdown]
#  ### Convert sentence into TFIDF sequence

# %%
# vectorizer = TfidfVectorizer(max_features=30000)
# x_text = vectorizer.fit_transform(da['text'])
vectorizer = pickle.load(open('Homework-8-9/vectorizer', 'rb'))
x_text = vectorizer.transform(da['text'])

# %%
# save model
import pickle
with open('vectorizer', 'wb') as f:
    pickle.dump(vectorizer, f)

with open('lr_model', 'wb') as f:
    pickle.dump(lr_model, f)

# %%
print(x_text.shape)
# Out:
# (89611, 30000)

# %% [markdown]
#  ### Decision Tree model

# %%
tree_model = DecisionTreeClassifier(class_weight={0:5, 1:4}, criterion='entropy',
    max_features=5000)
tree_model.fit(x_train, y_train)
get_performance(tree_model, x_test, y_test)
# Out:
# percision is: 0.9927984410743032
# recall is: 0.9912028421586871
# roc_auc is: 0.969366853178109
# confusion matrix:
# [[ 3070   170]
#  [  208 23436]]

# %% [markdown]
#  ### Train test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_text, da['label'], test_size=0.3) 
print(x_train.shape)
print(x_test.shape)
# Out:
# (62727, 30000)
# (26884, 30000)

# %%
pickle.dump(tree_model, open('tree_model', 'wb'))

# %% [markdown]
#  ### Build Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
def get_performance(model, X_, y_):
    y_hat = model.predict(X_)
    y_prob = model.predict_proba(X_)
    print('percision is: {}'.format(precision_score(y_, y_hat)))
    print('recall is: {}'.format(recall_score(y_, y_hat)))
    print('roc_auc is: {}'.format(roc_auc_score(y_, y_hat)))
    print('confusion matrix: \n{}'.format(confusion_matrix(y_, y_hat, labels=[0, 1])))

# %% [markdown]
#  ### Naive Bayes

# %%
# nb_model = GaussianNB()
# nb_model.fit(x_train.toarray(), y_train)
# get_performance(nb_model, x_test.toarray(), y_test)

# %% [markdown]
#  ### Logistic Regression

# %%
lr_model = LogisticRegression()
lr_model.fit(x_train, y_train)
get_performance(lr_model, x_test.toarray(), y_test)
# Out:
# /home/yikang/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# percision is: 0.9744950856384523
# recall is: 0.9932369600135261
# roc_auc is: 0.9012991991636136
# confusion matrix:
# [[ 2611   615]
#  [  160 23498]]

# %%
y_hat = lr_model.predict(x_test)
print(y_hat)
y_score = lr_model.predict_proba(x_test)[:,1]
print(roc_auc_score(y_test, y_score))
get_performance(lr_model, x_test.toarray(), y_test)
# Out:
# [1 1 1 ... 1 1 1]
# 0.9919014050550999
# percision is: 0.9744950856384523
# recall is: 0.9932369600135261
# roc_auc is: 0.9012991991636136
# confusion matrix:
# [[ 2611   615]
#  [  160 23498]]

# %%
# save model
import pickle
with open('vectorizer', 'wb') as f:
    pickle.dump(vectorizer, f)

with open('lr_model', 'wb') as f:
    pickle.dump(lr_model, f)

# %% [markdown]
#  ### Decision Tree model

# %%
tree_model = DecisionTreeClassifier(class_weight={0:5, 1:4}, criterion='entropy',
    max_features=5000)
tree_model.fit(x_train, y_train)
get_performance(tree_model, x_test, y_test)
# Out:
# percision is: 0.9912306714679093
# recall is: 0.9890100600219799
# roc_auc is: 0.9624219549954909
# confusion matrix:
# [[ 3019   207]
#  [  260 23398]]

# %%
pickle.dump(tree_model, open('tree_model', 'wb'))

# %% [markdown]
#  ### Naive Bayes

# %%
# nb_model = GaussianNB()
# nb_model.fit(x_train.toarray(), y_train)
# get_performance(nb_model, x_test.toarray(), y_test)
